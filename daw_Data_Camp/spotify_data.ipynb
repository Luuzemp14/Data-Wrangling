# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Daten einlesen

# %%
data = pd.read_csv("spotify_data.csv")

# %% [markdown]
# ### Übersicht über Daten erhalten. (head, info, shape, describe

# %%
data.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  603 non-null    int64
#  1   title       603 non-null    object
#  2   artist      603 non-null    object
#  3   top genre   603 non-null    object
#  4   year        603 non-null    int64
#  5   bpm         603 non-null    int64
#  6   nrgy        603 non-null    int64
#  7   dnce        603 non-null    int64
#  8   dB          603 non-null    int64
#  9   live        603 non-null    int64
#  10  val         603 non-null    int64
#  11  dur         603 non-null    int64
#  12  acous       603 non-null    int64
#  13  spch        603 non-null    int64
#  14  pop         603 non-null    int64
# dtypes: int64(12), object(3)
# memory usage: 70.8+ KB

# %%
data.shape
#hat 603 Zeilen und 15 Spalten
# Out:
# (603, 15)

# %%
data.describe()
# Out:
#        Unnamed: 0         year         bpm        nrgy        dnce  \
# count  603.000000   603.000000  603.000000  603.000000  603.000000
# mean   302.000000  2014.592040  118.545605   70.504146   64.379768
# std    174.215384     2.607057   24.795358   16.310664   13.378718
# min      1.000000  2010.000000    0.000000    0.000000    0.000000
# 25%    151.500000  2013.000000  100.000000   61.000000   57.000000
# 50%    302.000000  2015.000000  120.000000   74.000000   66.000000
# 75%    452.500000  2017.000000  129.000000   82.000000   73.000000
# max    603.000000  2019.000000  206.000000   98.000000   97.000000
#
#                dB        live         val         dur       acous        spch  \
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean    -5.578773   17.774461   52.225539  224.674959   14.326700    8.358209
# std      2.798020   13.102543   22.513020   34.130059   20.766165    7.483162
# ...

# %% [markdown]
# ### Daten sortieren und arragieren

# %%
artists = data.sort_values("artist")
artists.head()
# Out:
#      Unnamed: 0                        title               artist  \
# 31           32  My First Kiss - feat. Ke$ha                3OH!3
# 229         230         She Looks So Perfect  5 Seconds of Summer
# 249         250                Say Something    A Great Big World
# 21           22         Whataya Want from Me         Adam Lambert
# 37           38                 If I Had You         Adam Lambert
#
#           top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  \
# 31        dance pop  2010  138    89    68  -4    36   83  192      1     8
# 229        boy band  2014  160    95    49  -4    33   44  202      0    13
# 249      neo mellow  2014  138    15    45  -9     9    9  229     87     3
# 21   australian pop  2010  186    68    44  -5     6   45  227      1     5
# 37   australian pop  2010  131    91    65  -4    37   79  228      1    11
#
#      pop
# 31    62
# 229   71
# 249   61
# 21    66
# 37    59

# %% [markdown]
# ### Subset erstellen mit nur Titel und Artist

# %%
artists_title = data[["artist", "title"]]
artists_title.head()
# Out:
#        artist                 title
# 0       Train      Hey, Soul Sister
# 1      Eminem  Love The Way You Lie
# 2       Kesha               TiK ToK
# 3   Lady Gaga           Bad Romance
# 4  Bruno Mars  Just the Way You Are

# %% [markdown]
# ### Filtern nach songs die nach 2015 herausgekommen sind

# %%
songs_after_2015 = data[data["year"] > 2014]
songs_after_2015.head(10)
# Out:
#      Unnamed: 0                                              title  \
# 268         269                                  Thinking out Loud
# 269         270                               I'm Not The Only One
# 270         271                                          The Hills
# 271         272                                      Love Yourself
# 272         273                                        Uptown Funk
# 273         274                                  Take Me To Church
# 274         275                                              Sugar
# 275         276                                              Sorry
# 276         277                                    FourFiveSeconds
# 277         278  Love Me Like You Do - From "Fifty Shades Of Grey"
#
#              artist                  top genre  year  bpm  nrgy  dnce  dB  \
# 268      Ed Sheeran                        pop  2015   79    45    78  -6
# 269       Sam Smith                        pop  2015   82    49    68  -6
# ...
